# %%
import numpy as np

medallas_csv_url = "./medallas.csv"
array = np.genfromtxt(medallas_csv_url)
array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       3 medallas_csv_url = "./medallas.csv"
# ----> 4 array = np.genfromtxt(medallas_csv_url)
#       5 array
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:2350, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2348 # Raise an exception ?
#    2349 if invalid_raise:
# -> 2350     raise ValueError(errmsg)
#    2351 # Issue a warning ?
#    2352 else:
#    2353     warnings.warn(errmsg, ConversionWarning, stacklevel=2)
#
# ValueError: Some errors were detected !
#     Line #15 (got 2 columns instead of 1)
# ...

# %%
import numpy as np

medallas_csv_url = "./medallas.csv"
array = np.genfromtxt(medallas_csv_url,delimiter=',', filling_values=0)
array
# Out:
# array([[  0.,   0.,   0.,   0.,   0.],
#        [  0.,   1.,   2.,   3.,   0.],
#        [  0.,   2.,   2.,   4.,   0.],
#        [ 17.,   7.,  22.,  46.,   0.],
#        [  1.,   1.,   5.,   7.,   0.],
#        [  0.,   3.,   4.,   7.,   0.],
#        [  2.,   0.,   0.,   2.,   0.],
#        [  0.,   1.,   0.,   1.,   0.],
#        [  1.,   3.,   3.,   7.,   0.],
#        [  3.,   1.,   3.,   7.,   0.],
#        [  1.,   0.,   0.,   1.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,   8.,  21.,   0.],
#        [  3.,   1.,   2.,   6.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,  11.,  24.,   0.],
#        [  2.,   4.,   6.,  12.,   0.],
#        [  0.,   4.,   1.,   5.,   0.],
#        [  3.,   3.,   2.,   8.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   3.,   5.,  15.,   0.],
#        [  4.,   4.,   3.,  11.,   0.],
#        [  3.,   4.,   4.,  11.,   0.],
#        [  0.,   3.,   2.,   5.,   0.],
# ...

# %%
import numpy as np

medallas_csv_url = "./medallas.csv"
# remove the header
array = np.genfromtxt(medallas_csv_url,delimiter=',', filling_values=0,skip_header=1)
array
# Out:
# array([[  0.,   1.,   2.,   3.,   0.],
#        [  0.,   2.,   2.,   4.,   0.],
#        [ 17.,   7.,  22.,  46.,   0.],
#        [  1.,   1.,   5.,   7.,   0.],
#        [  0.,   3.,   4.,   7.,   0.],
#        [  2.,   0.,   0.,   2.,   0.],
#        [  0.,   1.,   0.,   1.,   0.],
#        [  1.,   3.,   3.,   7.,   0.],
#        [  3.,   1.,   3.,   7.,   0.],
#        [  1.,   0.,   0.,   1.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,   8.,  21.,   0.],
#        [  3.,   1.,   2.,   6.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,  11.,  24.,   0.],
#        [  2.,   4.,   6.,  12.,   0.],
#        [  0.,   4.,   1.,   5.,   0.],
#        [  3.,   3.,   2.,   8.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   3.,   5.,  15.,   0.],
#        [  4.,   4.,   3.,  11.,   0.],
#        [  3.,   4.,   4.,  11.,   0.],
#        [  0.,   3.,   2.,   5.,   0.],
#        [  2.,   1.,   0.,   3.,   0.],
# ...

# %%
import numpy as np

medallas_csv_url = "./medallas.csv"
# remove the header
array = np.genfromtxt(medallas_csv_url,delimiter=',', filling_values=0,skip_header=1, dtype=int)
array
# Out:
# array([[  0,   1,   2,   3,   0],
#        [  0,   2,   2,   4,   0],
#        [ 17,   7,  22,  46,   0],
#        [  1,   1,   5,   7,   0],
#        [  0,   3,   4,   7,   0],
#        [  2,   0,   0,   2,   0],
#        [  0,   1,   0,   1,   0],
#        [  1,   3,   3,   7,   0],
#        [  3,   1,   3,   7,   0],
#        [  1,   0,   0,   1,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,   8,  21,   0],
#        [  3,   1,   2,   6,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,  11,  24,   0],
#        [  2,   4,   6,  12,   0],
#        [  0,   4,   1,   5,   0],
#        [  3,   3,   2,   8,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   3,   5,  15,   0],
#        [  4,   4,   3,  11,   0],
#        [  3,   4,   4,  11,   0],
#        [  0,   3,   2,   5,   0],
#        [  2,   1,   0,   3,   0],
#        [  1,   1,   4,   6,   0],
#        [ 39,  41,  33, 113,   0],
#        [  1,   0,   1,   2,   0],
# ...

# %%
array_ejm = np.arange(1,7).reshape(2,3)
array_ejm_url = "./array_ejm.txt"
# fmt='%d' -> to generate number type int
np.savetxt(array_ejm_url, array_ejm, delimiter=',', fmt='%d')
