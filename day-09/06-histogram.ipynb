# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ventas_csv_url ='./Ventas.csv'
ventas = pd.read_csv(ventas_csv_url)

plt.hist(ventas['Producto'])
# plt.title('Histograma de Precios')
# plt.xlabel('Precio')
# plt.ylabel('Frecuencia')
# plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
numeros = np.random.randn(10000)
numeros

plt.hist(numeros, bins=30, alpha=0.5, color='red', edgecolor='black', histtype='barstacked')
plt.show()

# %%
xa = np.random.randn(10000)
xb = np.random.randn(5000)
xc = np.random.randn(1000)

plt.hist([xa, xb, xc], histtype='stepfilled', alpha=0.5)
plt.show()
